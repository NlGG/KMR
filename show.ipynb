# %%
# %matplotlib inline

# %%
from KMR import KMR

# %%
seq = KMR(0.333, 10, 0.01, mode=0)
seq.sample_path(init=2,sample_size=10000, plot=1)
seq.compute_stationary_distribution()
seq.plot(0)
seq.plot(1)

# %%
sim = KMR(0.333, 10, 0.01, mode=1)
sim.sample_path(init=10,sample_size=10000,plot=1)
sim.compute_stationary_distribution()
sim.plot(0)
sim.plot(1)
